# %%
import spacy
from spacy import displacy

# %%
# !pip install https://huggingface.co/spacy/xx_ent_wiki_sm/resolve/main/xx_ent_wiki_sm-any-py3-none-any.whl
# Out:
# Collecting xx-ent-wiki-sm==any
#   Downloading https://huggingface.co/spacy/xx_ent_wiki_sm/resolve/main/xx_ent_wiki_sm-any-py3-none-any.whl (11.1 MB)
#      ---------------------------------------- 11.1/11.1 MB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from xx-ent-wiki-sm==any) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (1.10.14)
# Requirement already satisfied: jinja2 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (1.26.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (0.1.4)
# Requirement already satisfied: colorama in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (8.1.3)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nares\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->xx-ent-wiki-sm==any) (2.1.1)
# Installing collected packages: xx-ent-wiki-sm
# Successfully installed xx-ent-wiki-sm-3.7.0
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
nlp_wk = spacy.load("xx_ent_wiki_sm")

# %%
# Text with nlp
doc = nlp_wk(" Multiple tornado warnings were issued for parts of New York on Sunday night.The first warning, which expired at 9 p.m., covered the Bronx, Yonkers and New Rochelle. More than 2 million people live in the impacted area.")

# %%
# Display Entities
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Multiple tornado warnings were issued for parts of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  on Sunday night.The first warning, which expired at 9 p.m., covered the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bronx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yonkers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  and
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New Rochelle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . More than 2 million people live in the impacted area.</div></span>

# %%
import os
import pandas as pd

# %%
df
# Out:
#         File             Location  start  end
# 0      0.txt              Marigny     61   62
# 1      0.txt       French Quarter     89   91
# 2      0.txt    Mississippi River     99  101
# 3      0.txt     Faubourg Marigny    132  134
# 4      0.txt                  Rue    239  240
# ...      ...                  ...    ...  ...
# 2156  32.txt       Collier County     67   69
# 2157  32.txt              Florida    146  147
# 2158  32.txt  County Commissioner    215  217
# 2159  32.txt  County Commissioner    288  290
# 2160  32.txt       Collier County    296  298
#
# [2161 rows x 4 columns]

# %%
import pandas as pd
import geopandas as gpd
import geopy
import matplotlib.pyplot as plt
from geopy.extra.rate_limiter import RateLimiter

locator = geopy.geocoders.Nominatim(user_agent="mygeocoder")
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
df["address"] = df["Location"].apply(geocode)

# %%
df
# Out:
#        File          Location  start  end  \
# 0  doc1.txt             Paris      6    7
# 1  doc1.txt      Eiffel Tower      9   11
# 2  doc1.txt       Seine River     20   22
# 3  doc3.txt      Grand Canyon      1    3
# 4  doc3.txt    Colorado River     19   21
# 5  doc2.txt             Tokyo      4    5
# 6  doc2.txt  Shibuya Crossing     12   14
# 7  doc2.txt         Ueno Park     19   21
#
#                                              address
# 0  (Paris, Île-de-France, France métropolitaine, ...
# 1  (Tour Eiffel, 5, Avenue Anatole France, Quarti...
# 2  (Seine River, Division No. 2, Manitoba, Canada...
# 3  (Grand Canyon, Coconino County, Arizona, Unite...
# 4  (Colorado River, United States, (36.755005, -1...
# 5                (東京都, 日本, (35.6821936, 139.762221))
# 6  (渋谷駅前, 道玄坂, 道玄坂二丁目, 道玄坂, 渋谷区, 東京都, 150-0043, 日...
# 7  (上野公園, 伊賀市, 三重県, 518-0873, 日本, (34.77090095, 1...

# %%
df["coordinates"] = df["address"].apply(lambda loc: tuple(loc.point) if loc else None)
df[[‘latitude’, ‘longitude’, ‘altitude’]] = pd.DataFrame(df[‘coordinates’].tolist(), index=df.index)
df.latitude.isnull().sum()
df = df[pd.notnull(df[“latitude”])]
